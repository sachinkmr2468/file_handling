# %% [markdown]
# # Python program to read character by character from a file

# %%
f = open('text2.txt','r+')

# %%
for i in f:
    for j in i.split():
        print(j)
# Out:
# yourname
# whatappeen
# sonam
# brother
# sister
# mynameyourname
# whatapp

# %%
f.seek(0)
# Out:
# 0

# %%
for i in f:
    print(i)
# Out:
# yourname whatappeen
#
# sonam
#
# brother
#
# sister
#
# mynameyourname whatapp

# %%
f.seek(0)
# Out:
# 0

# %%
for i in f:
    for j in i:
        print(j, end=' ')
# Out:
# y o u r n a m e   w h a t a p p e e n
#  s o n a m
#  b r o t h e r
#  s i s t e r
#  m y n a m e                                                                                                                                                                                                                                                                                                           y o u r n a m e   w h a t a p p

# %%
pwd()
# Out:
# 'C:\\Users\\SACHIN KUMAR\\Downloads\\Untitled Folder'
